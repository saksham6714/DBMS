# %%
# Out:
# MySQL Connector Installed Successfully!

# %%
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 insert_student(
#       2     111111,
#       3     "Rahul",
#       4     "0987654321",
#
# Cell In[9], line 2, in insert_student(sapid, name, mobile, dept, email)
#       1 def insert_student(sapid, name, mobile, dept, email):
# ----> 2     cur = cnx.cursor()
#       3
#       4     query = """
#       5     INSERT INTO xyz1
#
# File c:\Users\Devansh\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:841, in CMySQLConnection.cursor(self, buffered, raw, prepared, cursor_class, dictionary, read_timeout, write_timeout)
#     839 self.handle_unread_result(prepared)
#     840 if not self.is_connected():
# --> 841     raise OperationalError("MySQL Connection not available.")
#     842 if read_timeout or write_timeout:
#     843     warnings.warn(
# ...

# %%
# Out:
# (1254, 'devansh', '1234567890', 'Computer', 'dev@gmail.com')
# (111111, 'Devansh', '0987654321', 'EXTC', 'abcdef@gmail.com')
